# %% [markdown]
# # Regression using Multi-Layer Neural Network
# ## (for sine wave data)

# %% [markdown]
# # Library

# %%
import numpy as np

import torch
import torch.nn as nn # for neural network models
import torch.optim as optim # for optimization 
import torch.nn.init as init # for initialization 

from matplotlib import pyplot as plt

# %% [markdown]
# # simple data

# %%
# true data
N = 100
X = np.linspace(-np.pi, np.pi, N).reshape(N, 1)
real_y = np.sin(X)

# add noise
y = real_y + 0.1*np.random.randn(N, 1)

# shuffle
idx = np.random.permutation(N)
X_ = X[idx]
y_ = y[idx]

# %%
# show
plt.figure()
plt.plot(X, real_y)
plt.scatter(X, y)
plt.show()

# %% [markdown]
# # Split train / test dataset

# %%
n = N-20

X_train = X_[:n]
y_train = y_[:n]
X_test = X_[n:]
y_test = y_[n:]

# %%
plt.figure()
plt.scatter(X_train, y_train, label='train')
plt.scatter(X_test, y_test, label='test')
plt.legend()
plt.show()

# %% [markdown]
# # Regression using Multi-Layer Neural Network

# %% [markdown]
# ## Hyper parameter setting

# %%
learning_rate = 1e-1 # 보통 1e-4에서 시작해서 5, 10 단위로 증가시킴
epochs = 1000

# %% [markdown]
# ## Make model with pytorch (Gradient Descent)

# %%
# prepare data
X_train = torch.tensor(X_train, dtype = torch.float) # if X_train is numpy.array
label = torch.tensor(y_train, dtype = torch.float)

# prepare model
model = nn.Sequential(
        nn.Linear(1,1),
        nn.Sigmoid(),
        nn.Linear(1,1),
        )

# prepare optimization and loss function
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.1)

loss_array = [] # for visualization

# train the model
for i in range(epochs):
    optimizer.zero_grad() # tensor의 grad값을 초기화 (누적되기 때문)

    # forward propagation
    output = model(X_train)
    loss = loss_function(output, label)
    
    # backward propagation
    loss.backward()
    optimizer.step() # weight update
    
    loss_array.append(loss)
    
X_test = torch.tensor(X_test, dtype = torch.float)
X_ = torch.tensor(X_, dtype = torch.float)

y_train_pred = model(X_train)
y_whole_pred = model(X_)

y_train_pred = y_train_pred.detach().numpy() # detach() : tensor의 그라디언트 정보를 때내기
y_whole_pred = y_whole_pred.detach().numpy()

# %%
plt.figure()
plt.scatter(X_train, y_train_pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.legend()
plt.title('train data')
plt.show()

plt.figure()
plt.scatter(X_, y_whole_pred, label='pred')
plt.scatter(X_, y_, label='target')
plt.legend()
plt.title('whole data')
plt.show()

# %%
### plot loss
plt.figure()
plt.plot(loss_array)
plt.show()
            
plt.figure()
plt.scatter(X_train, y_train_pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.title('train data')
plt.show()

plt.figure()
plt.scatter(X_, y_whole_pred, label='pred')
plt.scatter(X_, y_, label='target')
plt.title('whole data')
plt.show()

# %% [markdown]
# # Change hidden layer's node number

# %%
# prepare data
X_train = X_train.clone().detach() # if X_train is torch.tensor
label = label.clone().detach()

# prepare model
model = nn.Sequential(
        nn.Linear(1,10),
        nn.Sigmoid(),
        nn.Linear(10,1),
        )

# prepare optimziation and loss function 
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.1)

loss_array = []

# train the model
for i in range(epochs):
    optimizer.zero_grad()
    output = model(X_train)
    
    loss = loss_function(output, label)
    loss.backward()
    optimizer.step()
    
    loss_array.append(loss)
    
X_test = X_test.clone().detach()
X_ = X_.clone().detach()

y_train_pred = model(X_train)
y_whole_pred = model(X_)

y_train_pred = y_train_pred.detach().numpy()
y_whole_pred = y_whole_pred.detach().numpy()

# %%
### plot loss
plt.figure()
plt.plot(loss_array)
plt.show()
            
plt.figure()
plt.scatter(X_train, y_train_pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.title('train data')
plt.show()

plt.figure()
plt.scatter(X_, y_whole_pred, label='pred')
plt.scatter(X_, y_, label='target')
plt.title('whole data')
plt.show()

# %% [markdown]
# # Change Activation function from sigmoid to tanh

# %%
# prepare data
X_train = X_train.clone().detach() # if X_train is torch.tensor
label = label.clone().detach()

# prepare model
model = nn.Sequential(
        nn.Linear(1,10),
        nn.Tanh(),
        nn.Linear(10,10),
        nn.ReLU(),
        nn.Linear(10,1)
        )

# prepare optimziation and loss function 
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.1)

loss_array = []

# train the model
for i in range(epochs):
    optimizer.zero_grad()
    output = model(X_train)
    
    loss = loss_function(output, label)
    loss.backward()
    optimizer.step()
    
    loss_array.append(loss)
    
X_test = X_test.clone().detach()
X_ = X_.clone().detach()

y_train_pred = model(X_train)
y_whole_pred = model(X_)

y_train_pred = y_train_pred.detach().numpy()
y_whole_pred = y_whole_pred.detach().numpy()

# %%
### plot loss
plt.figure()
plt.plot(loss_array)
plt.show()
            
plt.figure()
plt.scatter(X_train, y_train_pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.legend()
plt.title('train data')
plt.show()

plt.figure()
plt.scatter(X_, y_whole_pred, label='pred')
plt.scatter(X_, y_, label='target')
plt.legend()
plt.title('whole data')
plt.show()

# %% [markdown]
# # Sum-up

# %%
#################### hyper parameter setting ####################
learning_rate=1e-1
epochs = 1000

h = 10 ### number of hidden layer nodes
act = nn.ReLU() ### activation function
#################################################################
# prepare data
X_train = torch.tensor(X_train, dtype = torch.float)
label = torch.tensor(y_train, dtype = torch.float)

# prepare model
model = nn.Sequential(
        nn.Linear(1,h),
        act,
        nn.Linear(h,1),
        )

# prepare optimziation and loss function 
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = learning_rate)

loss_array = []

# train the model
for i in range(epochs):
    optimizer.zero_grad() # tensor의 grad값을 초기화 (누적되기 때문)

    # forward propagation
    output = model(X_train)
    loss = loss_function(output, label)
    
    # backward propagation
    loss.backward()
    optimizer.step() # weight update
    
    loss_array.append(loss)
    
X_test = torch.tensor(X_test, dtype = torch.float)
X_ = torch.tensor(X_, dtype = torch.float)

y_train_pred = model(X_train)
y_whole_pred = model(X_)

y_train_pred = y_train_pred.detach().numpy()
y_whole_pred = y_whole_pred.detach().numpy()

### plot loss
plt.figure()
plt.plot(loss_array)
plt.show()
            
plt.figure()
plt.scatter(X_train, y_train_pred, label='pred')
plt.scatter(X_train, y_train, label='target')
plt.title('train data')
plt.show()

plt.figure()
plt.scatter(X_, y_whole_pred, label='pred')
plt.scatter(X_, y_, label='target')
plt.title('whole data')
plt.show()
# Out:
# /home/pirl/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
# /home/pirl/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/pirl/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
